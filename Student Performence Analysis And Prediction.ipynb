# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import joblib
import streamlit as st

# %%
df = pd.read_csv('C:\\Users\\USER-11\\Downloads\\ultimate_student_productivity_dataset_5000.csv')

# %%
df.shape
# Out:
# (5000, 21)

# %%
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline  \
# 0                81                  38              1                  0
# 1               111                 339              0                  0
# 2                68                 266              0                  1
# 3               113                 480              1                  1
# 4               121                  24              1                  0
#
#    internet_quality mental_health_score  focus_index  burnout_level  \
# 0              Good                  10        43.05          31.77
# 1              Good                   3        15.92          37.00
# 2              Good                   8        27.39          34.37
# 3              Poor                   3        22.31          77.31
# 4              Good                   8        38.11          39.53
#
#    productivity_score  exam_score
# 0               73.65       50.16
# 1               13.70        1.00
# 2               45.15       18.30
# 3               20.92        9.37
# 4               59.23       27.81
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# student_id                int64
# age                       int64
# gender                   object
# academic_level           object
# study_hours             float64
# self_study_hours        float64
# online_classes_hours    float64
# social_media_hours      float64
# gaming_hours            float64
# sleep_hours             float64
# screen_time_hours       float64
# exercise_minutes          int64
# caffeine_intake_mg        int64
# part_time_job             int64
# upcoming_deadline         int64
# internet_quality         object
# mental_health_score       int64
# focus_index             float64
# burnout_level           float64
# productivity_score      float64
# exam_score              float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of       student_id  age gender academic_level  study_hours  self_study_hours  \
# 0              1   18  Other    High School         7.64              1.56
# 1              2   18  Other    High School         2.21              2.22
# 2              3   22   Male    High School         3.45              0.00
# 3              4   17  Other    High School         5.75              2.08
# 4              5   19  Other    High School         6.83              1.72
# ...          ...  ...    ...            ...          ...               ...
# 4995        4996   20  Other  Undergraduate         3.93              1.42
# 4996        4997   24   Male    High School         4.00              0.00
# 4997        4998   22   Male  Undergraduate         5.63              2.52
# 4998        4999   17   Male  Undergraduate         3.58              2.83
# 4999        5000   22  Other  Undergraduate         5.60              4.14
#
#       online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# 0                     2.20                3.05          2.19         6.52
# 1                     2.10                1.65          2.55         5.97
# 2                     0.29                1.34          2.08         8.39
# 3                     3.01                2.27          2.20         6.31
# 4                     3.33                2.65          0.70         8.01
# ...                    ...                 ...           ...          ...
# 4995                  0.54                2.58          2.62         9.30
# 4996                  3.00                4.45          2.47         6.42
# 4997                  2.89                3.58          1.07         6.65
# 4998                  1.53                5.88          1.28         7.36
# 4999                  2.17                3.05          2.74         6.38
#
#       ...  exercise_minutes  caffeine_intake_mg  part_time_job  \
# 0     ...                81                  38              1
# 1     ...               111                 339              0
# 2     ...                68                 266              0
# 3     ...               113                 480              1
# 4     ...               121                  24              1
# ...   ...               ...                 ...            ...
# 4995  ...               113                 496              0
# 4996  ...               146                 411              0
# 4997  ...               123                 306              0
# 4998  ...                54                 304              1
# 4999  ...                24                 219              0
#
#       upcoming_deadline  internet_quality mental_health_score  focus_index  \
# 0                     0              Good                  10        43.05
# 1                     0              Good                   3        15.92
# 2                     1              Good                   8        27.39
# 3                     1              Poor                   3        22.31
# 4                     0              Good                   8        38.11
# ...                 ...               ...                 ...          ...
# 4995                  0              Good                   9        35.55
# 4996                  1              Poor                   5        16.87
# 4997                  1              Good                   7        23.85
# 4998                  1              Good                   4        13.04
# 4999                  1              Good                   3        29.98
#
#       burnout_level  productivity_score  exam_score
# 0             31.77               73.65       50.16
# 1             37.00               13.70        1.00
# 2             34.37               45.15       18.30
# 3             77.31               20.92        9.37
# 4             39.53               59.23       27.81
# ...             ...                 ...         ...
# 4995          33.24               48.83       22.51
# 4996          59.07               23.32        2.00
# 4997          47.72               41.09       27.89
# 4998          58.90               12.62        3.63
# 4999          61.01               34.72       10.76
#
# [5000 rows x 21 columns]>

# %%
df.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# 25%                1.320000            1.990000      0.670000     6.237500
# 50%                2.010000            2.980000      1.490000     7.010000
# 75%                2.690000            4.030000      2.340000     7.810000
# max                6.000000            8.280000      5.640000    10.000000
#
#        screen_time_hours  exercise_minutes  caffeine_intake_mg  part_time_job  \
# count        5000.000000       5000.000000         5000.000000    5000.000000
# mean            6.979588         74.535600          251.450400       0.498200
# std             2.486214         42.932293          143.842712       0.500047
# min             1.000000          0.000000            0.000000       0.000000
# 25%             5.280000         37.000000          129.000000       0.000000
# 50%             6.950000         75.000000          252.000000       0.000000
# 75%             8.710000        112.000000          376.000000       1.000000
# max            15.300000        149.000000          499.000000       1.000000
#
#        upcoming_deadline  mental_health_score  focus_index  burnout_level  \
# count        5000.000000          5000.000000  5000.000000    5000.000000
# mean            0.501400             5.507400    29.431616      45.615324
# std             0.500048             2.869145     9.962902      14.246591
# min             0.000000             1.000000     1.000000       1.000000
# 25%             0.000000             3.000000    22.567500      35.727500
# 50%             1.000000             5.000000    29.430000      45.690000
# 75%             1.000000             8.000000    36.242500      55.352500
# max             1.000000            10.000000    63.480000      97.580000
#
#        productivity_score   exam_score
# count         5000.000000  5000.000000
# mean            37.267716    18.803752
# std             16.849397    12.130840
# min              1.000000     1.000000
# 25%             25.290000     9.337500
# 50%             36.860000    18.010000
# 75%             49.142500    27.400000
# max             98.020000    64.090000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('gender')['exam_score'].mean()
# Out:
# gender
# Female    19.024742
# Male      18.919180
# Other     18.465391
# Name: exam_score, dtype: float64

# %%
sns.barplot(x='gender', y='exam_score', data=df)
plt.title("Average Exam Score by Gender")
plt.show()
plt.savefig("Average Exam Score by Gender")

# %%
df.groupby('internet_quality')['productivity_score'].mean()
# Out:
# internet_quality
# Average    37.446099
# Good       36.941672
# Poor       37.431896
# Name: productivity_score, dtype: float64

# %%
df.groupby(['gender','study_hours'])['exam_score'].mean()
# Out:
# gender  study_hours
# Female  0.00            6.57
#         0.01           10.52
#         0.02            1.00
#         0.05            1.00
#         0.07            1.00
#                        ...
# Other   9.48           42.51
#         9.61           37.92
#         9.63           37.95
#         9.90           32.54
#         10.55          38.22
# Name: exam_score, Length: 1956, dtype: float64

# %%
df.groupby('burnout_level')['productivity_score'].mean()
# Out:
# burnout_level
# 1.00     38.14
# 1.18     53.85
# 1.92     68.54
# 3.66     64.02
# 4.01     64.27
#          ...
# 87.58    67.56
# 87.98    30.32
# 91.11    15.54
# 93.41     1.00
# 97.58    17.83
# Name: productivity_score, Length: 3256, dtype: float64

# %%
sns.lineplot(x='burnout_level', y='productivity_score', data=df)
plt.title("Burnout vs Productivity")
plt.show()
plt.savefig("Burnout vs Productivity")

# %%
df.groupby('social_media_hours')['exam_score'].mean()
# Out:
# social_media_hours
# 0.00    20.729680
# 0.01    17.856667
# 0.03    19.360000
# 0.04    18.985000
# 0.05    17.504000
#           ...
# 7.81    12.390000
# 7.97    11.300000
# 8.20    28.160000
# 8.21     1.860000
# 8.28     8.860000
# Name: exam_score, Length: 662, dtype: float64

# %%
sns.scatterplot(x='social_media_hours', y='exam_score', data=df)
plt.title("Social Media Hours vs Exam Score")
plt.show()
plt.savefig("Social Media Hours vs Exam Score")

# %%
important_cols = ['study_hours','sleep_hours',
                  'social_media_hours',
                  'exam_score',
                  'productivity_score']

sns.heatmap(df[important_cols].corr(), annot=True, cmap='coolwarm')
plt.savefig('columns relations')

# %%
x =  df.drop(['exam_score','part_time_job','internet_quality'],axis=1)
y = df['exam_score']

# %%
numerical_cols = x.select_dtypes(include=['int64','float64']).columns.tolist()

# %%
categorical_cols = x.select_dtypes(include=['object']).columns.tolist()

# %%
numerical_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='mean')),
    ('scaler',StandardScaler())
])

# %%
categorical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num',numerical_transformer,numerical_cols),
    ('cat',categorical_transformer,categorical_cols)
])

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = Pipeline(steps=[
    ('pre',preprocessor),('reg',LinearRegression())
])

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['student_id', 'age',
#                                                    'study_hours',
#                                                    'self_study_hours',
#                                                    'online_classes_hours',
#                                                    'social_media_hours',
#                                                    'gaming_hours',
#                                                    'sleep_hours',
#                                                    'screen_time_hours',
#                                                    'exercise_minutes',
#                                                    'caffeine_intake_mg',
#                                                    'upcoming_deadline',
#                                                    'mental_health_score',
#                                                    'focus_index',
#                                                    'burnout_level',
#                                                    'productivity_score']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['gender',
#                                                    'academic_level'])])),
#                 ('reg', LinearRegression())])

# %%
y_pred = model.predict(X_test)

print(f'accuracy:{r2_score(y_test,y_pred)*100:.2f}')
# Out:
# accuracy:81.65

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model2 = Pipeline(steps=[
    ('pre',preprocessor),('reg',RandomForestRegressor(n_estimators=200,random_state=42))
     ])

# %%
model2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['student_id', 'age',
#                                                    'study_hours',
#                                                    'self_study_hours',
#                                                    'online_classes_hours',
#                                                    'social_media_hours',
#                                                    'gaming_hours',
#                                                    'sleep_hours',
#                                                    'screen_time_hours',
#                                                    'exercise_minutes',
#                                                    'caffeine_intake_mg',
#                                                    'upcoming_deadline',
#                                                    'mental_health_score',
#                                                    'focus_index',
#                                                    'burnout_level',
#                                                    'productivity_score']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['gender',
#                                                    'academic_level'])])),
#                 ('reg',
#                  RandomForestRegressor(n_estimators=200, random_state=42))])

# %%
y_pred2 = model2.predict(X_test)
print(f'accuracy:{r2_score(y_test,y_pred2)*100:.2f}')
# Out:
# accuracy:81.39

# %%
joblib.dump(model,'LinearRgression')
# Out:
# ['LinearRgression']

# %%
load = joblib.load('LinearRgression')
st.title('exam score prediction')
student_id = st.number_input('student_id')
age= st.number_input('age')
gender = st.selectbox('gender',['male','female'])
academic_level = st.selectbox('academic_level',['Postgraduate','High School','Undergraduate'])
study_hours = st.number_input('study_hours')
self_study_hours = st.number_input('self_study_hours')
online_classes_hours = st.number_input('online_classes_hours')
social_media_hours = st.number_input('social_media_hours')
gaming_hours = st.number_input('gaming_hours')
sleep_hours = st.number_input('sleep_hours')
screen_time_hours = st.number_input('screen_time_hours')
exercise_minutes = st.number_input('exercise_minutes')
caffeine_intake_mg = st.number_input('caffeine_intake_mg')
#part_time_job = st.number_input('part_time_job')
upcoming_deadline = st.number_input('upcoming_deadline')
#internet_quality = st.selectbox('internet_quality',['Good','Poor','Average'])
mental_health_score = st.number_input('mental_health_score')
focus_index = st.number_input('focus_index')
burnout_level = st.number_input('burnout_level')
productivity_score = st.number_input('productivity_scorem')

if st.button('predict'):
        data = pd.DataFrame({
              'student_id':[student_id],
                     'age':[age],
                  'gender':[gender],
          'academic_level':[academic_level],
             'study_hours':[study_hours],
        'self_study_hours':[self_study_hours],
    'online_classes_hours':[online_classes_hours],
      'social_media_hours':[social_media_hours],
            'gaming_hours':[gaming_hours],
             'sleep_hours':[sleep_hours],
       'screen_time_hours':[screen_time_hours],
        'exercise_minutes':[exercise_minutes],
      'caffeine_intake_mg':[caffeine_intake_mg],
          #'part_time_job ':[part_time_job],
       'upcoming_deadline':[upcoming_deadline],
       #'internet_quality ':[internet_quality],
     'mental_health_score':[mental_health_score],
             'focus_index':[focus_index],
           'burnout_level':[burnout_level],
     'productivity_score':[productivity_score]
    })
    
        
        prediction = load.predict(data)
        st.success(f'exam score prediction:{prediction[0]}')
# Out:
# 2026-02-28 15:03:09.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 15:03:09.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
